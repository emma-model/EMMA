# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

from call import read_scenarios
from analysis import  get_table, add_zeros, change_tec_lvl_name_to_alltec, market_value, electricity_balance, hydrogen_balance, pdc_pivot, load_factor, total_investment_costs, full_load_hours, variable_costs, DataHandler
from plot import colors_techs, stacked_bar_chart, draw_legend, PlotHandler
from renaming_SENTINEL import rename_df_index
from IPython.display import HTML

# %load_ext autoreload
# %autoreload 2

# %%
#code from: http://blog.nextgenetics.net/?e=102
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# # Greek Case Study

# %%
Greece = 'GRC'
scenario_file_GRC = 'scenarios_SENTINEL_CS_GR'      
    
scenarios_GRC = read_scenarios(scenario_file_GRC + '.yaml')
dh_GRC = DataHandler(scenarios_GRC)
ph_GRC = PlotHandler(dh_GRC);

# %% [markdown]
# ## Capacity

# %%
ph_GRC.plot_capacity(Greece);

# %% [markdown]
# ## Generation

# %%
ph_GRC.plot_electricity_balance(Greece);

# %% [markdown]
# ## Electricity Prices

# %%
ph_GRC.plot_pdc(Greece,(-25,300));
# Out:
# The y-axis of this figure is limited to (-25, 300).
#
# The maximum prices are:
#
# scenario    RF_2030  RF_2050      RE_2050  P2X_2050
# max_prices   3000.0   3000.0  2527.094558    3000.0
#
# The minimum prices are:
#
# scenario    RF_2030  RF_2050  RE_2050  P2X_2050
# min_prices      0.0      0.0      0.0       0.0

# %% [markdown]
# # European Case Study

# %%
Germany = 'GER'
scenario_file_EU = 'scenarios_SENTINEL_CS_EU'    
    
scenarios_EU = read_scenarios(scenario_file_EU + '.yaml')
dh_EU = DataHandler(scenarios_EU)
ph_EU = PlotHandler(dh_EU);

# %% [markdown]
# ## Capacity

# %%
ph_EU.plot_capacity(Germany);

# %% [markdown]
# ## Generation

# %%
ph_EU.plot_electricity_balance(Germany);

# %% [markdown]
# ## Electricity Prices

# %%
ph_EU.plot_pdc(Germany,(-20,300));
# Out:
# The y-axis of this figure is limited to (-20, 300).
#
# The maximum prices are:
#
# scenario    2030_EU_CT  2050_EU_CT  2030_EU_CN  2050_EU_CN
# max_prices      1000.0      1000.0      1000.0   859.01693
#
# The minimum prices are:
#
# scenario    2030_EU_CT  2050_EU_CT  2030_EU_CN  2050_EU_CN
# min_prices         0.0         0.0         0.0         0.0
